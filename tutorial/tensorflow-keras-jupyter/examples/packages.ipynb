# %%
# %pip list
# Out:
# Package              Version
# -------------------- ------------
# absl-py              0.9.0
# affine               2.3.0
# astor                0.8.1
# astropy              4.0.1.post1
# attrs                19.3.0
# backcall             0.1.0
# bleach               3.1.4
# cachetools           4.1.0
# certifi              2020.4.5.1
# chardet              3.0.4
# click                7.1.1
# click-plugins        1.1.1
# cligj                0.5.0
# cycler               0.10.0
# dask                 2.14.0
# decorator            4.4.2
# defusedxml           0.6.0
# entrypoints          0.3
# Fiona                1.8.13.post1
# gast                 0.2.2
# geopandas            0.7.0
# google-auth          1.14.1
# google-auth-oauthlib 0.4.1
# google-pasta         0.2.0
# grpcio               1.28.1
# h5py                 2.10.0
# idna                 2.9
# imageio              2.8.0
# imgaug               0.4.0
# importlib-metadata   1.6.0
# ipykernel            5.2.1
# ...
